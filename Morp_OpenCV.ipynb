# %% [markdown]
# reference : https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_morphological_ops/py_morphological_ops.html#morphological-ops

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('morph1.JPG',0)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
kernel = np.ones((17,17),np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

output  =[img,closing]
plt.rcParams["figure.figsize"] = [16,9]
for i in range(2):
    plt.subplot(1,2, i+1)
    plt.imshow(output[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('morph2.JPG',0)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
kernel = np.ones((17,17),np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

output  =[img,closing]
plt.rcParams["figure.figsize"] = [16,9]
for i in range(2):
    plt.subplot(1,2, i+1)
    plt.imshow(output[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# ### Morphological Operations on Faces

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('face1.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
kernel = np.ones((3,3),np.uint8)
dilation = cv2.dilate(img,kernel,iterations = 1)
erosion = cv2.erode(img,kernel,iterations = 1)

output  =[img,dilation,erosion]
titles=['Original','Filtered using Dilation','Filtered using Erosion']

plt.rcParams["figure.figsize"] = [16,9]
for i in range(3):
    plt.subplot(1,3, i+1)
    plt.imshow(output[i])
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('face1.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

output  =[img,dilation,erosion]
titles=['Original','Filtered using Opening','Filtered using Closing']

plt.rcParams["figure.figsize"] = [16,9]
for i in range(3):
    plt.subplot(1,3, i+1)
    plt.imshow(output[i])
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('face2.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
kernel = np.ones((3,3),np.uint8)
dilation = cv2.dilate(img,kernel,iterations = 1)
erosion = cv2.erode(img,kernel,iterations = 1)

output  =[img,dilation,erosion]
titles=['Original','Filtered using Dilation','Filtered using Erosion']

plt.rcParams["figure.figsize"] = [16,9]
for i in range(3):
    plt.subplot(1,3, i+1)
    plt.imshow(output[i])
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('face2.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

output  =[img,opening,closing]
titles=['Original','Filtered using Opening','Filtered using Closing']
plt.rcParams["figure.figsize"] = [16,9]
for i in range(3):
    plt.subplot(1,3, i+1)
    plt.title(titles[i])
    plt.imshow(output[i])
    plt.xticks([])
    plt.yticks
plt.show()

# %% [markdown]
# ### Filtering live video

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

cap = cv2.VideoCapture(0)

while(True):
    ret, frame = cap.read()
    kernel = np.ones((5,5),np.uint8)
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    closing = cv2.morphologyEx(frame, cv2.MORPH_CLOSE, kernel)
    cv2.imshow('Original',frame)
    cv2.imshow('Filtered',closing)
    
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()
